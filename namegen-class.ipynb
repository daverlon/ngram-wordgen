# %%
# take the core n-gram functionality and
# put it in a class

# %%
import numpy as np
from numpy.random import multinomial
import pandas as pd
from tqdm import tqdm

# %%
class NGramModel:
    
    def __init__(self, prepped_data: np.ndarray, n: int):
        
        self.data = prepped_data # data already padded with start/end token(s)
        self.n = n
        
        self.unique_chars = sorted(list(set(''.join(self.data))))
        self.stoi = { s:i for i,s in enumerate(self.unique_chars) }
        self.itos = { i:s for s,i in self.stoi.items() }
        
        # create ngram matrix
        mat_shape = (len(self.unique_chars),) * (self.n)
        self.ngrams = np.zeros(mat_shape)
        #print(self.ngrams.shape, mat_shape)
        
    def learn(self):
        self.count_ngrams()
        self.calculate_probabilities()
    
    def count_ngrams(self):
        for sample in tqdm(self.data,
                          desc=f"Counting {self.n}-Grams"):
            l = len(sample)
            nn = self.n - 1
            for i in range(l-nn):
                x = sample[i:i+nn]
                y = sample[i+nn]
                
                x_idx = tuple([self.stoi[c] for c in x])
                y_idx = self.stoi[y]
                
                self.ngrams[x_idx][y_idx] += 1

    def calculate_probabilities(self):
        total_its = np.prod(self.ngrams.shape[:-1])
        
        for idx in tqdm(np.ndindex(*self.ngrams.shape[:-1]),
                        total=total_its,
                        desc="    Calculating probabilities"):
            s = self.ngrams[idx].sum()
            if s != 0.0:
                self.ngrams[idx] /= s
    
    def forward(self):
        out = ''
        out += '<' * (self.n-1)
        
        while True:
            last = tuple([self.stoi[c] for c in out[-(self.n-1):]])
            probs = self.ngrams[last]
            pred_idx = multinomial(1, probs).argmax()
            pred_char = self.itos[pred_idx]
            if pred_char == '>': break
            
            out += pred_char
            
        return out.replace('<','')

# %%
# load dataset using pandas
dataset = pd.read_csv("datasets/names.txt").to_numpy()

def prep_dataset(data: np.ndarray, n: int):
    start_token = '<' * (n-1)
    end_token = '>'
    samples = []
    for sample in data:
        s = start_token + sample.item() + end_token
        samples.append(s)
    return samples

# %%
# create a model for n, starting from 2, to 6
models = [
    NGramModel(prep_dataset(dataset, i), i)
    for i in range(2, 7)
]

# call learn method for each model
for model in models:
    model.learn()
# Out:
# Counting 2-Grams: 100%|███████████████████████████████████| 32032/32032 [00:00<00:00, 324213.06it/s]
#     Calculating probabilities: 100%|████████████████████████████| 28/28 [00:00<00:00, 349525.33it/s]
# Counting 3-Grams: 100%|███████████████████████████████████| 32032/32032 [00:00<00:00, 293788.11it/s]
#     Calculating probabilities: 100%|██████████████████████████| 784/784 [00:00<00:00, 670678.02it/s]
# Counting 4-Grams: 100%|███████████████████████████████████| 32032/32032 [00:00<00:00, 281175.13it/s]
#     Calculating probabilities: 100%|██████████████████████| 21952/21952 [00:00<00:00, 902449.98it/s]
# Counting 5-Grams: 100%|███████████████████████████████████| 32032/32032 [00:00<00:00, 240888.93it/s]
#     Calculating probabilities: 100%|███████████████████| 614656/614656 [00:00<00:00, 1049095.72it/s]
# Counting 6-Grams: 100%|███████████████████████████████████| 32032/32032 [00:00<00:00, 176816.80it/s]
#     Calculating probabilities: 100%|███████████████| 17210368/17210368 [00:15<00:00, 1078958.24it/s]

# %%
# create 20 names for each model

n_preds = 50

results = {}
for n, model in enumerate(models):
    
    y = []
    for _ in range(n_preds):
        y.append(model.forward())
        
    results[f"{n+2}-Gram"] = y

# %%
df = pd.DataFrame(results)

df
# Out:
#                       2-Gram                   3-Gram  \
# 0          beryrmilelilarona                   jenzia
# 1             roslarararalea                khapospyn
# 2               khanethigase                     tayl
# 3                        jee                 simiyane
# 4                         br                   ariany
# 5                      eteti                     amer
# 6                         be                   everen
# 7                        zee                 kaylyani
# 8                    jaclish                      via
# 9                       keyl         jrundonandynluwa
# 10                    auviys                      ani
# 11                         s        hephemilikaikrion
# 12              yilanariyipe                  rhyohse
# 13               cararriydaa                      lyn
# 14                   warieen                   mariss
# 15                         e                      zia
# 16                     lyant                   chemir
# 17          ttyonohayaniarli                 arreneen
# 18                         l                daiblaran
# 19                       rya                    poley
# 20                      jeja              amsoluqayle
# 21                   melemaz                       ad
# 22                       kat                    lumar
# 23                         b                  bredell
# 24                      azax                       sa
# 25                         e        emminslechemaudse
# 26                jalindieyn                  berionn
# 27                gejanayidi                 najibawn
# 28                     ddozl               nahananiel
# 29                     daria        jaikaddakelasirah
# 30                     eshee                    adina
# 31                   nongnde                 aedrosia
# 32                      mabe           karitabbillaki
# 33                        al                     shli
# 34                        ph               aundrolion
# 35                 iquenohan                   jiriah
# 36                   derrine                    eilam
# 37                   eyaiali                  julleen
# 38                      jann                cudereyah
# 39                     xeman                       ah
# 40                  dasondor             brajattermee
# 41              soubrorasien                   zanvie
# 42                       seh                   kayare
# 43                    anyixx                    kolen
# 44                   ckaimoh                 zarysonn
# 45  maniynosordesaalaguranni                      jei
# 46                        an  alaylayngjakameinoxxina
# 47                      ckhe                icollance
# 48                        ah                      kel
# 49                      jend                  aharmon
#
#                               4-Gram           5-Gram      6-Gram
# 0                              jiaan             ward    termaine
# 1                                nah             anye          oz
# 2                                anh           iknoor   maddalynn
# 3                               brie          nayelli       fadil
# 4                            yamaris              jet      anvith
# 5                        cecileannah            eriya     senaida
# 6                               mily              yar     perceus
# 7                             josses      sauloralina      delsin
# 8                                ell            jason      madiha
# 9                                zey            edine      chanie
# 10                      aaralyxandro           domini       hanzo
# 11                               sah             deem    zephyrus
# 12                            deshok           adalei       keili
# 13                             billy          niaylah      rhylee
# 14                              reen            avell  maranathan
# 15                              jail           larose      samary
# 16                           dellory            gabri      estela
# 17                          karsonos            celin     payzlee
# 18                      giannaelisla            petal        mosa
# 19                          kyellena          leanina         kim
# 20                             advik             lira  kristianne
# 21                            rashan           ridwan      haydon
# 22                         gartavian             aiya       ethel
# 23                       nohemitcher             lend     avajade
# 24                             grace            marik       lenne
# 25                            aarynn             arie      dhyaan
# 26                              hari            saory      aadaya
# 27                              sace           audree      venice
# 28                            aurent           raygen      ariela
# 29                              dana             biak       ronza
# 30                             marsh        amelianna      saanjh
# 31                     maudricharter            amiah      corrie
# 32                        dulkaniyah            marie        tesa
# 33                            mariel            dmere      keiyon
# 34                               sar           alikoi       orvin
# 35                            jensen         ridgette     kameria
# 36                          breckaya           jahaan  karrington
# 37                               ita             riya     braxley
# 38                              viah  ebrahamadelynah      nathon
# 39                              ebio        modestynn       ziggy
# 40                         frittalyn            aveen     rachana
# 41                               mya           sollyn       niyan
# 42                        kavellonna            aryar      marily
# 43                            westin         kelliano       doria
# 44                             maley          blayden       jager
# 45                               tra           ozelle    aristian
# 46                        adeenakyla            aidan      caesyn
# 47                          kellwood       sidhaanika     cynthia
# 48  makyrianaimelouisabrislaynormiah          trevion        zoii
# 49                              lira            jamah  kiandreyan
